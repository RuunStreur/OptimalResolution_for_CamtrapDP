# %%
import pandas as pd
import numpy as np

# %%
observations = pd.read_csv('observations.csv')
media = pd.read_csv('media.csv')
events = pd.read_csv('events.csv')
deployments = pd.read_csv('deployments.csv')

alldata_list = (observations, 
                media, 
                events, 
                deployments)

# %%
# for data in alldata_list:
#     print(len(data))

observations
# observations.head()
# Out:
#                                            observationID  \
# 0      obs_20220801001635_artis_18_wildlifecamera1_20...
# 1      obs_20220801001635_artis_18_wildlifecamera1_20...
# 2      obs_20220801003924_artis_18_wildlifecamera1_20...
# 3      obs_20220801120024_artis_18_wildlifecamera1_20...
# 4      obs_20220802120027_artis_18_wildlifecamera1_20...
# ...                                                  ...
# 36538  obs_20231028183334_artis_24_wildlifecamera1_20...
# 36539  obs_20231028183332_artis_24_wildlifecamera1_20...
# 36540  obs_20231028183329_artis_24_wildlifecamera1_20...
# 36541  obs_20231028183327_artis_24_wildlifecamera1_20...
# 36542  obs_20231028183324_artis_24_wildlifecamera1_20...
#
#                    deploymentID  \
# 0      artis_18_wildlifecamera1
# 1      artis_18_wildlifecamera1
# 2      artis_18_wildlifecamera1
# 3      artis_18_wildlifecamera1
# 4      artis_18_wildlifecamera1
# ...                         ...
# 36538  artis_24_wildlifecamera1
# ...

# %%
mergedTest = observations.merge(events, on='eventID')
mergedTest
# Out:
#                                             observationID  \
# 0       obs_20220801001635_artis_18_wildlifecamera1_20...
# 1       obs_20220801001635_artis_18_wildlifecamera1_20...
# 2       obs_20220801001635_artis_18_wildlifecamera1_20...
# 3       obs_20220801001635_artis_18_wildlifecamera1_20...
# 4       obs_20220801001635_artis_18_wildlifecamera1_20...
# ...                                                   ...
# 202629  obs_20211029220821_artis_25_wildlifecamera1_20...
# 202630  obs_20211029220821_artis_25_wildlifecamera1_20...
# 202631  obs_20211029220821_artis_25_wildlifecamera1_20...
# 202632  obs_20211031120016_artis_25_wildlifecamera1_20...
# 202633  obs_20211031120016_artis_25_wildlifecamera1_20...
#
#                     deploymentID mediaID_x  \
# 0       artis_18_wildlifecamera1       NaN
# 1       artis_18_wildlifecamera1       NaN
# 2       artis_18_wildlifecamera1       NaN
# 3       artis_18_wildlifecamera1       NaN
# 4       artis_18_wildlifecamera1       NaN
# ...
